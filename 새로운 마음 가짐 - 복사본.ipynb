# %%
from autogluon.tabular import TabularDataset, TabularPredictor
train_data = TabularDataset('./train.csv')
test_data = TabularDataset('./test.csv')

# %%
label = 'Y_Class'
eval_metric = 'f1_macro'
time_limit = 3600 * 5

# %%
train_data
# Out:
#     PRODUCT_ID  Y_Class  Y_Quality         TIMESTAMP     LINE PRODUCT_CODE  \
# 0    TRAIN_000        1   0.533433   2022-06-13 5:14  T050304         A_31
# 1    TRAIN_001        2   0.541819   2022-06-13 5:22  T050307         A_31
# 2    TRAIN_002        1   0.531267   2022-06-13 5:30  T050304         A_31
# 3    TRAIN_003        2   0.537325   2022-06-13 5:39  T050307         A_31
# 4    TRAIN_004        1   0.531590   2022-06-13 5:47  T050304         A_31
# ..         ...      ...        ...               ...      ...          ...
# 593  TRAIN_593        1   0.526546  2022-09-08 14:30  T100306         T_31
# 594  TRAIN_594        0   0.524022  2022-09-08 22:38  T050304         A_31
# 595  TRAIN_595        0   0.521289  2022-09-08 22:47  T050304         A_31
# 596  TRAIN_596        1   0.531375  2022-09-08 14:38  T100304         O_31
# 597  TRAIN_597        1   0.533702  2022-09-08 14:46  T100306         O_31
#
# ...

# %%
test_data
# Out:
#     PRODUCT_ID         TIMESTAMP     LINE PRODUCT_CODE  X_1   X_2  X_3   X_4  \
# 0     TEST_000   2022-09-09 2:01  T100306         T_31  2.0  94.0  0.0  45.0
# 1     TEST_001   2022-09-09 2:09  T100304         T_31  2.0  93.0  0.0  45.0
# 2     TEST_002   2022-09-09 8:42  T100304         T_31  2.0  95.0  0.0  45.0
# 3     TEST_003  2022-09-09 10:56  T010305         A_31  NaN   NaN  NaN   NaN
# 4     TEST_004  2022-09-09 11:04  T010306         A_31  NaN   NaN  NaN   NaN
# ..         ...               ...      ...          ...  ...   ...  ...   ...
# 305   TEST_305  2022-11-05 11:18  T100306         T_31  2.0  91.0  0.0  45.0
# 306   TEST_306  2022-11-05 16:39  T100304         T_31  2.0  96.0  0.0  45.0
# 307   TEST_307  2022-11-05 16:47  T100306         T_31  2.0  91.0  0.0  45.0
# 308   TEST_308  2022-11-05 20:53  T100306         T_31  2.0  95.0  0.0  45.0
# 309   TEST_309  2022-11-05 21:01  T100306         T_31  2.0  87.0  0.0  45.0
#
# ...

# %%
import pandas as pd
import random
import os
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
seed_everything(37) # Seed 고정

# %%
train_label = train_data['Y_Class']

# %%
train_data.drop('PRODUCT_ID',axis = 1, inplace = True)
test_data.drop('PRODUCT_ID',axis = 1, inplace = True)

train_data.drop('TIMESTAMP',axis = 1, inplace = True)
test_data.drop('TIMESTAMP',axis = 1, inplace = True)

#train_data.drop('Y_Class',axis = 1, inplace = True)
#train_data.drop('Y_Quality',axis = 1, inplace = True)

# %%
train_data
# Out:
#      Y_Class  Y_Quality     LINE PRODUCT_CODE   X_1   X_2  X_3   X_4   X_5  \
# 0          1   0.533433  T050304         A_31   NaN   NaN  NaN   NaN   NaN
# 1          2   0.541819  T050307         A_31   NaN   NaN  NaN   NaN   NaN
# 2          1   0.531267  T050304         A_31   NaN   NaN  NaN   NaN   NaN
# 3          2   0.537325  T050307         A_31   NaN   NaN  NaN   NaN   NaN
# 4          1   0.531590  T050304         A_31   NaN   NaN  NaN   NaN   NaN
# ..       ...        ...      ...          ...   ...   ...  ...   ...   ...
# 593        1   0.526546  T100306         T_31   2.0  95.0  0.0  45.0  10.0
# 594        0   0.524022  T050304         A_31   NaN   NaN  NaN   NaN   NaN
# 595        0   0.521289  T050304         A_31   NaN   NaN  NaN   NaN   NaN
# 596        1   0.531375  T100304         O_31  40.0  94.0  0.0  45.0  11.0
# 597        1   0.533702  T100306         O_31  21.0  87.0  0.0  45.0  10.0
#
# ...

# %%
test_data
# Out:
#         LINE PRODUCT_CODE  X_1   X_2  X_3   X_4   X_5  X_6   X_7   X_8  ...  \
# 0    T100306         T_31  2.0  94.0  0.0  45.0  10.0  0.0  51.0  10.0  ...
# 1    T100304         T_31  2.0  93.0  0.0  45.0  11.0  0.0  45.0  10.0  ...
# 2    T100304         T_31  2.0  95.0  0.0  45.0  11.0  0.0  45.0  10.0  ...
# 3    T010305         A_31  NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN  ...
# 4    T010306         A_31  NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN  ...
# ..       ...          ...  ...   ...  ...   ...   ...  ...   ...   ...  ...
# 305  T100306         T_31  2.0  91.0  0.0  45.0  10.0  0.0  51.0  10.0  ...
# 306  T100304         T_31  2.0  96.0  0.0  45.0  11.0  0.0  45.0  10.0  ...
# 307  T100306         T_31  2.0  91.0  0.0  45.0  10.0  0.0  50.0  10.0  ...
# 308  T100306         T_31  2.0  95.0  0.0  45.0  10.0  0.0  51.0  10.0  ...
# 309  T100306         T_31  2.0  87.0  0.0  45.0  10.0  0.0  51.0  10.0  ...
#
# ...

# %%
# qualitative to quantitative
#qual_col = ['LINE', 'PRODUCT_CODE']

#for i in qual_col:
    #le = LabelEncoder()
    #le = le.fit(train_data[i])
    #train_data[i] = le.transform(train_data[i])
    
    #for label in np.unique(test_data[i]): 
        #if label not in le.classes_: 
           # '''le.classes_ = np.append(le.classes_, label)
    #test_data[i] = le.transform(test_data[i]) 
#print('Done.')'''

# %%
#df["preTestScore"].fillna( df["preTestScore"].mean(), inplace=True)

# 데이터 전처리 -> 평균으로 
train_data = train_data.fillna(train_data.mean())
test_data = test_data.fillna(test_data.mean())
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7560\1244770396.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   train_data = train_data.fillna(train_data.mean())
# C:\Users\User\AppData\Local\Temp\ipykernel_7560\1244770396.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   test_data = test_data.fillna(test_data.mean())

# %%
train_data
# Out:
#      Y_Class  Y_Quality     LINE PRODUCT_CODE        X_1        X_2  X_3  \
# 0          1   0.533433  T050304         A_31   2.409742  95.123209  0.0
# 1          2   0.541819  T050307         A_31   2.409742  95.123209  0.0
# 2          1   0.531267  T050304         A_31   2.409742  95.123209  0.0
# 3          2   0.537325  T050307         A_31   2.409742  95.123209  0.0
# 4          1   0.531590  T050304         A_31   2.409742  95.123209  0.0
# ..       ...        ...      ...          ...        ...        ...  ...
# 593        1   0.526546  T100306         T_31   2.000000  95.000000  0.0
# 594        0   0.524022  T050304         A_31   2.409742  95.123209  0.0
# 595        0   0.521289  T050304         A_31   2.409742  95.123209  0.0
# 596        1   0.531375  T100304         O_31  40.000000  94.000000  0.0
# 597        1   0.533702  T100306         O_31  21.000000  87.000000  0.0
#
#       X_4       X_5  X_6  ...   X_2866   X_2867   X_2868   X_2869   X_2870  \
# ...

# %%
test_data
# Out:
#         LINE PRODUCT_CODE       X_1       X_2  X_3   X_4        X_5  X_6  \
# 0    T100306         T_31  2.000000  94.00000  0.0  45.0  10.000000  0.0
# 1    T100304         T_31  2.000000  93.00000  0.0  45.0  11.000000  0.0
# 2    T100304         T_31  2.000000  95.00000  0.0  45.0  11.000000  0.0
# 3    T010305         A_31  4.337449  94.44856  0.0  45.0  10.271605  0.0
# 4    T010306         A_31  4.337449  94.44856  0.0  45.0  10.271605  0.0
# ..       ...          ...       ...       ...  ...   ...        ...  ...
# 305  T100306         T_31  2.000000  91.00000  0.0  45.0  10.000000  0.0
# 306  T100304         T_31  2.000000  96.00000  0.0  45.0  11.000000  0.0
# 307  T100306         T_31  2.000000  91.00000  0.0  45.0  10.000000  0.0
# 308  T100306         T_31  2.000000  95.00000  0.0  45.0  10.000000  0.0
# 309  T100306         T_31  2.000000  87.00000  0.0  45.0  10.000000  0.0
#
#            X_7        X_8  ...     X_2866     X_2867     X_2868     X_2869  \
# ...

# %%
# 데이터 전처리 - 최빈값으로 하는 것이 분류에 도움이 되는 것인가
# train_data 내에서 테스트 분리
# from sklearn.model_selection import train_test_split
# x_train, x_test, y_train, y_test = train_test_split(train_data, train_label, test_size = 0.3,random_state = 777)

# %%
train_data
# Out:
#      Y_Class  Y_Quality     LINE PRODUCT_CODE        X_1        X_2  X_3  \
# 0          1   0.533433  T050304         A_31   2.409742  95.123209  0.0
# 1          2   0.541819  T050307         A_31   2.409742  95.123209  0.0
# 2          1   0.531267  T050304         A_31   2.409742  95.123209  0.0
# 3          2   0.537325  T050307         A_31   2.409742  95.123209  0.0
# 4          1   0.531590  T050304         A_31   2.409742  95.123209  0.0
# ..       ...        ...      ...          ...        ...        ...  ...
# 593        1   0.526546  T100306         T_31   2.000000  95.000000  0.0
# 594        0   0.524022  T050304         A_31   2.409742  95.123209  0.0
# 595        0   0.521289  T050304         A_31   2.409742  95.123209  0.0
# 596        1   0.531375  T100304         O_31  40.000000  94.000000  0.0
# 597        1   0.533702  T100306         O_31  21.000000  87.000000  0.0
#
#       X_4       X_5  X_6  ...   X_2866   X_2867   X_2868   X_2869   X_2870  \
# ...

# %%
train_label
# Out:
# 0      1
# 1      2
# 2      1
# 3      2
# 4      1
#       ..
# 593    1
# 594    0
# 595    0
# 596    1
# 597    1
# Name: Y_Class, Length: 598, dtype: int64

# %%
x_train
# Out:
#      Y_Class  Y_Quality     LINE PRODUCT_CODE         X_1         X_2  X_3  \
# 485        1   0.532157  T100306         T_31    2.000000   91.000000  0.0
# 165        1   0.528425  T100304         T_31  103.000000   96.000000  0.0
# 529        1   0.534211  T100304         T_31    2.000000   97.000000  0.0
# 253        1   0.529075  T100306         T_31    2.000000   93.000000  0.0
# 255        0   0.515083  T050304         A_31    2.409742   95.123209  0.0
# ..       ...        ...      ...          ...         ...         ...  ...
# 423        1   0.531570  T100306         T_31    2.000000   91.000000  0.0
# 116        0   0.523714  T010305         A_31    2.409742   95.123209  0.0
# 71         1   0.534486  T010305         A_31    2.409742   95.123209  0.0
# 571        1   0.525916  T100304         O_31    4.000000  100.000000  0.0
# 103        1   0.529952  T100304         T_31    2.000000  102.000000  0.0
#
# ...

# %%
y_test
# Out:
# 546    0
# 401    1
# 564    2
# 393    1
# 262    2
#       ..
# 283    2
# 305    1
# 166    1
# 65     1
# 373    1
# Name: Y_Class, Length: 180, dtype: int64

# %%
y_train
# Out:
# 485    1
# 165    1
# 529    1
# 253    1
# 255    0
#       ..
# 423    1
# 116    0
# 71     1
# 571    1
# 103    1
# Name: Y_Class, Length: 418, dtype: int64

# %%
predictor = TabularPredictor(
    label=label, eval_metric=eval_metric
).fit(train_data, presets='best_quality', time_limit=time_limit)
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20230214_173408\"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=0, num_bag_folds=5, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 18000s
# AutoGluon will save models to "AutogluonModels\ag-20230214_173408\"
# AutoGluon Version:  0.6.2
# Python Version:     3.9.13
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# Train Data Rows:    598
# Train Data Columns: 2878
# Label Column: Y_Class
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == int, but few unique label-values observed).
# 	3 unique label values:  [1, 2, 0]
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Train Data Class Count: 3
# ...

# %%
predictor.leaderboard(silent = True) # 예측 우수 모델 오름차순 정렬
# Out:
#                       model  score_val  pred_time_val     fit_time  \
# 0       WeightedEnsemble_L2   0.997686       0.181567    38.906160
# 1           LightGBM_BAG_L1   0.997686       0.181567    37.087909
# 2      LightGBMLarge_BAG_L1   0.995666       0.171866   220.965965
# 3           CatBoost_BAG_L1   0.995652       1.546769  7540.310647
# 4            XGBoost_BAG_L1   0.995434       0.312484    54.810109
# 5         LightGBMXT_BAG_L1   0.941052       0.281234    55.279881
# 6   RandomForestGini_BAG_L1   0.731112       1.462603     2.452953
# 7     NeuralNetTorch_BAG_L1   0.684253       8.509333    42.343239
# 8   RandomForestEntr_BAG_L1   0.682322       1.437407     2.492557
# 9    NeuralNetFastAI_BAG_L1   0.652432      29.678382    76.265442
# 10    ExtraTreesEntr_BAG_L1   0.633214       1.484279     2.093602
# 11    ExtraTreesGini_BAG_L1   0.629421       1.446426     2.093599
# 12    KNeighborsDist_BAG_L1   0.421442       0.031226     0.548696
# ...

# %%
model_to_use = predictor.get_model_best() # 가장 좋은 모델 보기 
#model_pred = predictor.predict(x_test, model=model_to_use)
model_pred = predictor.predict(test_data, model=model_to_use)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\autogluon\features\generators\abstract.py in transform(self, X)
#     328                 # therefore, try avoid copying by checking the expected features first.
# --> 329                 X = X[self.features_in]
#     330         except KeyError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#
# ...

# %%
train_data

# %%
#train_data 내에서 테스트 분리
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(train_data, train_label, test_size = 0.3,random_state = 777)

# %%
import sklearn.metrics as metrics
pred = predictor.predict(x_test)
pred_proba = predictor.predict_proba(x_test)[:1]
eval = [(x_test,y_test)]

# %%
from sklearn.metrics import accuracy_score, recall_score, f1_score, precision_score, roc_auc_score
from sklearn.metrics import confusion_matrix

def get_clf_eval(y_test, y_pred=None, pred_proba=None):
    confusion = confusion_matrix(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='micro')
    recall = recall_score(y_test, y_pred, average='micro')
    F1 = f1_score(y_test, y_pred, average = 'micro')
    #AUC = roc_auc_score(y_test, y_pred, pred_proba)

    print('오차행렬:\n', confusion)
    print('\n정확도: {:.4f}'.format(accuracy))
    print('정밀도: {:.4f}'.format(precision))
    print('재현율: {:.4f}'.format(recall))
    print('F1: {:.4f}'.format(F1))
    #print('AUC: {:.4f}'.format(AUC))

# %%
get_clf_eval(y_test,pred,pred_proba)

# %%
submission = pd.read_csv('./sample_submission.csv')

# %%
submission["Y_Class"] = model_pred
submission.head()
submission.to_csv('./auto.csv', index=False)
